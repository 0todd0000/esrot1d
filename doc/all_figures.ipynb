# %% [markdown]
# # Figure generation code
#
# This notebooks generates all figures from the main manuscript.
#
# - Code details for each figure can be found in the .py scripts in the same directory as this notebook.
# - Below only figure numbers are provided; please refer to the manuscript for captions.

# %%
import os
import esrot1d as e1d
os.chdir(  os.path.join( e1d.dirREPO, 'analysis', 'figs')  )

# %% [markdown]
# <br>
# <br>
#
# ## Figure 1

# %%
# %run fig_oa

# %% [markdown]
# <br>
# <br>
#
# ## Figure 2

# %%
# %run fig_dp

# %% [markdown]
# <br>
# <br>
#
# ## Figure 3

# %%
# %run fig_randn1d

# %% [markdown]
# <br>
# <br>
#
# ## Figure 4

# %%
# %run fig_sim

# %% [markdown]
# <br>
# <br>
#
# ## Figure 5

# %%
# %run fig_oa_es

# %% [markdown]
# <br>
# <br>
#
# ## Figure 6

# %%
# %run fig_oa_res

# %% [markdown]
# <br>
# <br>
#
# ## Figure 7

# %%
# %run fig_oa_es_posthoc
